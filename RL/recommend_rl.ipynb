# %%
import csv
import pandas as pd

# %%
#先建立好第_次推薦的資料夾，更改user_id、num
user_id = 'chiouchingyi'
num = 3
data_folder = 'data/output/'
filename = 'record_output_0' + str(num) + '.csv'
filepath = data_folder + user_id + '/' + str(num) + '/' + filename
print('輸入data: ',filepath)
# Out:
# data/output/chiouchingyi/3/record_output_03.csv

# %%
df = pd.read_csv(filepath)
hybrid_df = pd.read_csv('csv/hybrid20tracks_sim_outputEUCcsv.csv')

# %%
#聽大於28秒的歌曲
track_L = []
similarity_L = []
for i in range(0,len(df)):
    track = df['track_id'][i]
    track_L.append(track)
print('喜歡的tracks: ',track_L)
# Out:
# ['00AJ22EiTqG74qdgHVKVDM', '00AlGnzeNVYmilww5OFUw8', '00JA27dAnIPXljobCwtS36', '00RYw42tKwXecTaVay3BKl', '00Tv62iZ42zDjrWYu8Rxjp']

# %%
#在hybrid的csv挑選聽>28秒的歌曲

filename2 = 'record_output_p_0' + str(num) + '.csv'
filepath2 = data_folder + user_id + '/' + str(num) + '/' + filename2
print('聽大於28秒的歌曲data: ',filepath2)

with open(filepath2, "w", newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['id','h_top1','h_top2','h_top3','h_top4','h_top5','h_top6','h_top7','h_top8','h_top9','h_top10','h_top11','h_top12','h_top13','h_top14','h_top15','h_top16','h_top17','h_top18','h_top19','h_top20'])

    for w in range(0,len(track_L)):
        select = hybrid_df.loc[hybrid_df['id'] == track_L[w]]
        select_0 = select.iat[0,0]
        select_1 = select.iat[0,1]
        select_2 = select.iat[0,2]
        select_3 = select.iat[0,3]
        select_4 = select.iat[0,4]
        select_5 = select.iat[0,5]
        select_6 = select.iat[0,6]
        select_7 = select.iat[0,7]
        select_8 = select.iat[0,8]
        select_9 = select.iat[0,9]
        select_10 = select.iat[0,10]
        select_11 = select.iat[0,11]
        select_12 = select.iat[0,12]
        select_13 = select.iat[0,13]
        select_14 = select.iat[0,14]
        select_15 = select.iat[0,15]
        select_16 = select.iat[0,16]
        select_17 = select.iat[0,17]
        select_18 = select.iat[0,18]
        select_19 = select.iat[0,19]
        select_20 = select.iat[0,20]
        
        Table = [[select_0,select_1,select_2,select_3,select_4,select_5,select_6,select_7,select_8,select_9,select_10,select_11,select_12,select_13,select_14,select_15,select_16,select_17,select_18,select_19,select_20]]    
        writer.writerows(Table)
# Out:
# data/output/chiouchingyi/3/record_output_p_03.csv

# %%
#開啟挑選過的 CSV
select_df = pd.read_csv(filepath2)
select_df.head()
# Out:
#                        id                                          h_top1  \
# 0  00AJ22EiTqG74qdgHVKVDM  ['7fsAiUOy63nKXmEyALsbFE', 1.9244967982996697]
# 1  00AlGnzeNVYmilww5OFUw8  ['4QfNJwawl1ZcrfQbA0ohPl', 2.0806199547353113]
# 2  00JA27dAnIPXljobCwtS36  ['7Ipw32rwmsEhbf5IBQGmAI', 1.8585491903993496]
# 3  00RYw42tKwXecTaVay3BKl  ['6JEqJbL1brIBySspoKU2CL', 2.0657414370528304]
# 4  00Tv62iZ42zDjrWYu8Rxjp   ['6L42Utj3rnzJsJXwhUUwmw', 2.739633674203769]
#
#                                            h_top2  \
# 0  ['48D7dzCJNFVd2697AW3wBM', 1.9523773203279138]
# 1  ['0ak19JnF6mxmCD9ExJcPXq', 2.3044522148413007]
# 2  ['5q9d5StKZ8LEO1XTDNrt9O', 1.8830903218199846]
# 3  ['5u6vkDnOyaf8LsteDAj2ub', 2.1558602712784527]
# 4   ['0OAyZn9pGuuL2FJih1PM58', 3.025578355448385]
#
#                                            h_top3  \
# 0  ['7AwU1wxdM4XBMUIuQI4Arb', 1.9781855748199735]
# 1  ['5ZqPGaJyCvJtznQnX7XOiM', 2.3170361934913584]
# 2  ['3DRUH4dR9qrEtD7D2ZpjMY', 1.8946619342474014]
# 3   ['1fiKURoz6s2OXZhMkhF488', 2.188598648460267]
# 4  ['5tXKUlGgXbUkr3cyT1ivWn', 3.0577266301382307]
#
#                                            h_top4  \
# 0  ['2Ax40aWlG4xafoOilB9G26', 2.0060784357903576]
# 1  ['2KCrp7O8yf3Aa2yJGioxYU', 2.3385272664911643]
# 2  ['70NDHCtO4wGl11G5YgQuUL', 1.9115330396409285]
# 3  ['51Rg6NudgisCagiBqB625f', 2.2237356554403935]
# 4   ['0aO0JVI9S2shiUjhRa6h0g', 3.063990364716725]
#
#                                            h_top5  \
# 0   ['1nukLnD50ey3rfs6jNnMJa', 2.030110306510905]
# 1   ['77It1fz8dwAVneUbZA55W0', 2.356066186956362]
# 2  ['1tjfYeFu90zhXtY8PEHNZC', 1.9585818944158713]
# 3   ['00518PumkDdn560MsfLofT', 2.226126109214816]
# 4  ['5AKlnLpP3WLwZseNbjquND', 3.0886516885102226]
#
#                                            h_top6  \
# 0    ['4QaeQX43q3OdWE4JQxomF8', 2.03076579316355]
# 1  ['0gLQ6jhJsyYfl7PrD1RZ7X', 2.3634445949612815]
# 2   ['3STqgOS8Gnn0BQFHVbMIEI', 1.965587880650532]
# 3  ['4fpw5HAONttQfdqEtAhP0f', 2.2520145931433113]
# 4  ['1E1uGhNdBe6Dddbgs2KqtZ', 3.1166250416494816]
#
#                                            h_top7  \
# 0  ['2tELyJbKEVgwVBg48nK1hl', 2.0341128046604107]
# 1  ['7LVHVU3tWfcxj5aiPFEW4Q', 2.3736629618598006]
# 2  ['5M4yti0QxgqJieUYaEXcpw', 2.0089039826428063]
# 3  ['4amWrWgHzevTvWEPQY9Ujn', 2.2526427523425148]
# 4  ['1LwVrOwwPJPU5lVuQDPnGA', 3.1192459241815893]
#
#                                            h_top8  \
# 0  ['5Gfrwqe12AAmQjCVuSBktn', 2.0417901150634594]
# 1  ['79wvYwZgtfcnCwBI8XIep8', 2.3787102375539666]
# 2  ['2t2XbxRZ2Oqh2Z6rTMvhAO', 2.0123920842481327]
# 3  ['7xYy4fuiPfFEAsjz3H93Sl', 2.2580330856345716]
# 4   ['1BIZXYxk5ACcNibwCH5MXw', 3.120284820131675]
#
#                                            h_top9  ...  \
# 0   ['58TaFP5j5i9swOf584yon2', 2.042901331234708]  ...
# 1  ['18WYpqbNvkCXHTeyN2WG8l', 2.3959085079114333]  ...
# 2  ['51xBgzcyzojRpqFW2ICQAB', 2.0241110485368177]  ...
# 3  ['4bypMBt3Gq0QOAUPW6q9vD', 2.2597890781802463]  ...
# 4   ['7cA4MFh8Dsq23pVmkjXS8S', 3.155460036948014]  ...
#
#                                           h_top11  \
# 0   ['6MueWGuuijpLhRz0nUUqbW', 2.097545901041461]
# 1   ['2l7njxIZf3LEN9k061vcYa', 2.425901987063601]
# 2  ['73VwzWVHroWygiQ7SzGxgD', 2.0664388462885435]
# 3  ['3ilPTn5Jj7k4cP97wllXoh', 2.3086431944841608]
# 4   ['2x7h2ABCBEifwpDgNOGHGm', 3.188336610537898]
#
#                                           h_top12  \
# 0  ['0VwSYUon26FltmonOhgOFA', 2.1222585258552744]
# 1  ['0O9pHkUWSuQ3nIB26pPBTT', 2.4622312456112683]
# 2   ['7soCzpKbEzoNPSElsvflL7', 2.076676570665414]
# 3   ['6oNZ0WxqptE7V0qpjtyJ4a', 2.317347946937485]
# 4    ['0emoJVldapc3xGkD7MDgtV', 3.19008012127438]
#
#                                           h_top13  \
# 0   ['0Zrug5Ry3x6x60lohpEU0C', 2.124189324721632]
# 1   ['0zZucBnwVPo4f40LzmkDmW', 2.465217725113725]
# 2  ['7BKSYLTBHVWDYEyhAtX7UG', 2.1043332285638536]
# 3  ['3pTHh8iYearZ6hCWvLvbX9', 2.3245239583311266]
# 4  ['6ic8OlLUNEATToEFU3xmaH', 3.1998692807108036]
#
#                                           h_top14  \
# 0  ['7rMpCmqTU9Z2UcizZqhepP', 2.1309190669275475]
# 1  ['0pqnGHJpmpxLKifKRmU6WP', 2.4675634048547517]
# 2  ['27SKGriQA1EKLQAc1u0A9W', 2.1213519077815035]
# 3   ['0mj74TvfDiLtBBQvCzW3DL', 2.336316652810585]
# 4   ['5oSzsYZYu2oCOq8RIhMOHF', 3.203643008449317]
#
#                                           h_top15  \
# 0    ['6700Z4Izi8EbB6JNthU6Ma', 2.13477322404459]
# 1   ['6qfyoyyQGIReGRyWXsRTkr', 2.477592668980067]
# 2  ['5kH6mdE69WtXHGByvFRdsF', 2.1224359650572375]
# 3  ['6EzwwR07OGk7fh0EaXaWIA', 2.3517241137588014]
# 4  ['2mWb172p8SCACG6Peh3Qmt', 3.2174562552989054]
#
#                                           h_top16  \
# 0  ['2LMbweC2G8iLeEMOd4G6Le', 2.1401443583878477]
# 1  ['4ttUYy7HMYQ0nhfllLJNPR', 2.4885935051515378]
# 2  ['6oAUtgnsT5JifP2E1ceeJJ', 2.1359995192825796]
# 3   ['1Uf1wYxIbhy2U4Y5bgunNi', 2.359107744204519]
# 4   ['1tQ6po8BWXwUoY4LDXTrPU', 3.223961089676439]
#
#                                           h_top17  \
# 0   ['7dWgVTfUOnshsgX8KxV2Kh', 2.145325808025126]
# 1  ['2Dtn6xdm8SZcHPrto79eSK', 2.5008592559424137]
# 2  ['3koOoLN69AAiw5JCQNaZMe', 2.1438767406150987]
# 3  ['0U6Vg6RUmzADUO0Y9fVKft', 2.3749396099420235]
# 4  ['6T74sWvcHvSAO5prlk5dDw', 3.2246683704655283]
#
#                                           h_top18  \
# 0   ['4QeqcrhcEbnKr31j2aKVRK', 2.150705775090506]
# 1    ['4PeCvFYN5SHXbYZukRqJBf', 2.50693419900155]
# 2  ['5f2xi7GxToAUNySilFbppk', 2.1444313095919663]
# 3  ['4J2aKHa57MFj3zHhQitZDM', 2.3787083476150044]
# 4  ['4qzoHxgp42ylb18ga1SWTL', 3.2259479315766413]
#
#                                           h_top19  \
# 0  ['4cDjymWoZJ9eTvVO29wQvq', 2.1514900209688888]
# 1  ['7xGeM7ITK2lu8Q96DUFBa2', 2.5082781591900085]
# 2  ['4jJ9JnGw9JXL7X5Qz5l5D8', 2.1445419735161684]
# 3   ['44r0cJV79SmDgFah7Zgnvn', 2.380876676742204]
# 4  ['2OjhdYB4TFyIcf1UYcy7oT', 3.2323521749197845]
#
#                                          h_top20
# 0  ['6NFyWDv5CjfwuzoCkw47Xf', 2.151516082599907]
# 1  ['4hE6RC3dwTRm5q817dtAMf', 2.514636841505495]
# 2  ['6l2Q66TlfZqzbRkFrZOMT1', 2.149956428838079]
# 3  ['3kSE08EYzWQSAf6o1v2U4V', 2.396078315982829]
# 4  ['0fAoPbcLqVYS11D3Eds7J7', 3.244474429808095]
#
# [5 rows x 21 columns]

# %%
select_df.iat[0,2]
# Out:
# "['48D7dzCJNFVd2697AW3wBM', 1.9523773203279138]"

# %%
#排序sort相似性的值

filename3 = 'record_output_s_0' + str(num) + '.csv'
filepath3 = data_folder + user_id + '/' + str(num) + '/' + filename3
print('相似性排序後的data: ',filepath3)

similarity_list = []

with open(filepath3, "w", newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['id','similarity'])
    for i in range(0,len(select_df)):
        for j in range(1,21):
            #print(i,j)
            data = select_df.iat[i,j]
            data_re = data.replace('[','').replace(']','').replace(' ','')
            data_sp = data_re.split(',')
            rec_track = data_sp[0].replace("'",'')
            similarity = 1 - (float(data_sp[1])/10) #EUC值越小越好
            similarity_list.append(similarity)
            
            row = [[rec_track,similarity]]
            writer.writerows(row)
# Out:
# data/output/chiouchingyi/3/record_output_s_03.csv

# %%
#取推薦之20首歌曲
table_df = pd.read_csv(filepath3)
table_df_sort = table_df.sort_values(by = "similarity", ascending=False) #ascending=False降序

print('前20高分歌曲：')
table_df_sort.head(20)
# Out:
# 前20高分歌曲：
#                         id  similarity
# 40  7Ipw32rwmsEhbf5IBQGmAI    0.814145
# 41  5q9d5StKZ8LEO1XTDNrt9O    0.811691
# 42  3DRUH4dR9qrEtD7D2ZpjMY    0.810534
# 43  70NDHCtO4wGl11G5YgQuUL    0.808847
# 0   7fsAiUOy63nKXmEyALsbFE    0.807550
# 1   48D7dzCJNFVd2697AW3wBM    0.804762
# 44  1tjfYeFu90zhXtY8PEHNZC    0.804142
# 45  3STqgOS8Gnn0BQFHVbMIEI    0.803441
# 2   7AwU1wxdM4XBMUIuQI4Arb    0.802181
# 3   2Ax40aWlG4xafoOilB9G26    0.799392
# 46  5M4yti0QxgqJieUYaEXcpw    0.799110
# 47  2t2XbxRZ2Oqh2Z6rTMvhAO    0.798761
# 48  51xBgzcyzojRpqFW2ICQAB    0.797589
# 4   1nukLnD50ey3rfs6jNnMJa    0.796989
# 5   4QaeQX43q3OdWE4JQxomF8    0.796923
# 6   2tELyJbKEVgwVBg48nK1hl    0.796589
# 49  3JilapcaOXzjR9gtvCY8FO    0.796035
# 7   5Gfrwqe12AAmQjCVuSBktn    0.795821
# 8   58TaFP5j5i9swOf584yon2    0.795710
# 60  6JEqJbL1brIBySspoKU2CL    0.793426

# %%
#去除重複推薦之歌曲
final_table = table_df_sort.iloc[0:20]
print('檢查重複歌曲：')
print(final_table['id'].duplicated())
# Out:
# 檢查重複歌曲：
# 40    False
# 41    False
# 42    False
# 43    False
# 0     False
# 1     False
# 44    False
# 45    False
# 2     False
# 3     False
# 46    False
# 47    False
# 48    False
# 4     False
# 5     False
# 6     False
# 49    False
# 7     False
# 8     False
# 60    False
# Name: id, dtype: bool

# %%
final_table_new = final_table.drop_duplicates(subset=['id'], keep='first')
print('去除重複推薦之歌曲：')
print(final_table_new)
print('列表長度：',len(final_table_new))
# Out:
# 去除重複推薦之歌曲：
#                         id  similarity
# 40  7Ipw32rwmsEhbf5IBQGmAI    0.814145
# 41  5q9d5StKZ8LEO1XTDNrt9O    0.811691
# 42  3DRUH4dR9qrEtD7D2ZpjMY    0.810534
# 43  70NDHCtO4wGl11G5YgQuUL    0.808847
# 0   7fsAiUOy63nKXmEyALsbFE    0.807550
# 1   48D7dzCJNFVd2697AW3wBM    0.804762
# 44  1tjfYeFu90zhXtY8PEHNZC    0.804142
# 45  3STqgOS8Gnn0BQFHVbMIEI    0.803441
# 2   7AwU1wxdM4XBMUIuQI4Arb    0.802181
# 3   2Ax40aWlG4xafoOilB9G26    0.799392
# 46  5M4yti0QxgqJieUYaEXcpw    0.799110
# 47  2t2XbxRZ2Oqh2Z6rTMvhAO    0.798761
# 48  51xBgzcyzojRpqFW2ICQAB    0.797589
# 4   1nukLnD50ey3rfs6jNnMJa    0.796989
# 5   4QaeQX43q3OdWE4JQxomF8    0.796923
# 6   2tELyJbKEVgwVBg48nK1hl    0.796589
# 49  3JilapcaOXzjR9gtvCY8FO    0.796035
# 7   5Gfrwqe12AAmQjCVuSBktn    0.795821
# 8   58TaFP5j5i9swOf584yon2    0.795710
# 60  6JEqJbL1brIBySspoKU2CL    0.793426
# 列表長度： 20

# %%
#匯出最終推薦之CSV
filename4 = 'record_output_f_0' + str(num) + '.csv'
filepath4 = data_folder + user_id + '/' + str(num) + '/' + filename4
print(filepath4)

if len(final_table_new) < 20:
    diff = 20 - len(final_table_new)
    print('差：',diff)
    insert = table_df_sort[20:20+diff]
    final_table_insert = final_table_new.append(insert)
    print('---------------------------------------------------------------------')
    print('最終推薦之歌曲：')
    print(final_table_insert)
    print('列表長度：',len(final_table_insert))
    final_table_insert.to_csv(filepath4)
else:
    final_table.to_csv(filepath4)
    print('最終推薦之歌曲：')
    print(final_table_new)
# Out:
# data/output/chiouchingyi/3/record_output_f_03.csv
# 最終推薦之歌曲：
#                         id  similarity
# 40  7Ipw32rwmsEhbf5IBQGmAI    0.814145
# 41  5q9d5StKZ8LEO1XTDNrt9O    0.811691
# 42  3DRUH4dR9qrEtD7D2ZpjMY    0.810534
# 43  70NDHCtO4wGl11G5YgQuUL    0.808847
# 0   7fsAiUOy63nKXmEyALsbFE    0.807550
# 1   48D7dzCJNFVd2697AW3wBM    0.804762
# 44  1tjfYeFu90zhXtY8PEHNZC    0.804142
# 45  3STqgOS8Gnn0BQFHVbMIEI    0.803441
# 2   7AwU1wxdM4XBMUIuQI4Arb    0.802181
# 3   2Ax40aWlG4xafoOilB9G26    0.799392
# 46  5M4yti0QxgqJieUYaEXcpw    0.799110
# 47  2t2XbxRZ2Oqh2Z6rTMvhAO    0.798761
# 48  51xBgzcyzojRpqFW2ICQAB    0.797589
# 4   1nukLnD50ey3rfs6jNnMJa    0.796989
# 5   4QaeQX43q3OdWE4JQxomF8    0.796923
# 6   2tELyJbKEVgwVBg48nK1hl    0.796589
# 49  3JilapcaOXzjR9gtvCY8FO    0.796035
# 7   5Gfrwqe12AAmQjCVuSBktn    0.795821
# 8   58TaFP5j5i9swOf584yon2    0.795710
# 60  6JEqJbL1brIBySspoKU2CL    0.793426
