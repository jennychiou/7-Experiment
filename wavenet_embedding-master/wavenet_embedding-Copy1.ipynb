# %%
import os
import csv
# import umap
import json
import librosa
import numpy as np
import matplotlib.pyplot as plt
# from sklearn import preprocessing
# from sklearn.manifold import TSNE
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import MinMaxScaler
from magenta.models.nsynth import utils
from magenta.models.nsynth.wavenet import fastgen
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8026ebfe6646> in <module>
#       3 # import umap
#       4 import json
# ----> 5 import librosa
#       6 import numpy as np
#       7 import matplotlib.pyplot as plt
#
# D:\Anaconda3\envs\magenta\lib\site-packages\librosa\__init__.py in <module>
#      10 # And all the librosa sub-modules
#      11 from . import cache
# ---> 12 from . import core
#      13 from . import beat
#      14 from . import decompose
#
# D:\Anaconda3\envs\magenta\lib\site-packages\librosa\core\__init__.py in <module>
#     108
#     109 from .time_frequency import *  # pylint: disable=wildcard-import
# --> 110 from .audio import *  # pylint: disable=wildcard-import
#     111 from .spectrum import *  # pylint: disable=wildcard-import
#     112 from .pitch import *  # pylint: disable=wildcard-import
#
# D:\Anaconda3\envs\magenta\lib\site-packages\librosa\core\audio.py in <module>
#       8 import audioread
#       9 import numpy as np
# ---> 10 import scipy.signal
#      11 import scipy.fftpack as fft
#      12 import resampy
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\signal\__init__.py in <module>
#     320
#     321 from .bsplines import *
# --> 322 from .filter_design import *
#     323 from .fir_filter_design import *
#     324 from .ltisys import *
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\signal\filter_design.py in <module>
#      16 from numpy.polynomial.polynomial import polyval as npp_polyval
#      17
# ---> 18 from scipy import special, optimize, fftpack
#      19 from scipy.special import comb, factorial
#      20 from scipy._lib._numpy_compat import polyvalfromroots
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\optimize\__init__.py in <module>
#     385
#     386 from .optimize import *
# --> 387 from ._minimize import *
#     388 from ._root import *
#     389 from ._root_scalar import *
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\optimize\_minimize.py in <module>
#      28 from ._trustregion_krylov import _minimize_trust_krylov
#      29 from ._trustregion_exact import _minimize_trustregion_exact
# ---> 30 from ._trustregion_constr import _minimize_trustregion_constr
#      31
#      32 # constrained minimization
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\optimize\_trustregion_constr\__init__.py in <module>
#       2
#       3
# ----> 4 from .minimize_trustregion_constr import _minimize_trustregion_constr
#       5
#       6 __all__ = ['_minimize_trustregion_constr']
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\optimize\_trustregion_constr\minimize_trustregion_constr.py in <module>
#       2 import time
#       3 import numpy as np
# ----> 4 from scipy.sparse.linalg import LinearOperator
#       5 from .._differentiable_functions import VectorFunction
#       6 from .._constraints import (
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\sparse\linalg\__init__.py in <module>
#     115 from .dsolve import *
#     116 from .interface import *
# --> 117 from .eigen import *
#     118 from .matfuncs import *
#     119 from ._onenormest import *
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\sparse\linalg\eigen\__init__.py in <module>
#       9 from __future__ import division, print_function, absolute_import
#      10
# ---> 11 from .arpack import *
#      12 from .lobpcg import *
#      13
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\sparse\linalg\eigen\arpack\__init__.py in <module>
#      20 from __future__ import division, print_function, absolute_import
#      21
# ---> 22 from .arpack import *
#
# D:\Anaconda3\envs\magenta\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in <module>
#      43 __all__ = ['eigs', 'eigsh', 'svds', 'ArpackError', 'ArpackNoConvergence']
#      44
# ---> 45 from . import _arpack
#      46 import numpy as np
#      47 import warnings
#
# ImportError: DLL load failed: 找不到指定的程序。

# %%
import file_load
video_path = "./dataset"
name = ".mp3"

file_list, file_name, folder_list, folder_name = file_load.file_path(video_path, name)

for mp3, name in zip(file_list, file_name):
    save_path = mp3.replace('.mp3','')
    print(save_path)
    wave, sr = librosa.load(mp3,sr = 16000)
    audio_size = np.size(wave)
    print(wave.shape)
    split_size = 480000
    count = 0
    for split_point in range(0, audio_size, split_size):
        if count<1:
            split_audio = wave[split_point : split_point + split_size]
            np.save(save_path+'_{}'.format(count), split_audio)
            print("wave split {} OK".format(split_audio.shape))
        count += 1
# Out:
# ./dataset/no8/Old School Turntables
# (480654,)
# wave split (480000,) OK
# ./dataset/no8/Say what’s on your mind
# (480654,)
# wave split (480000,) OK
# ./dataset/no8/NO THANXXX
# (480654,)
# wave split (480000,) OK
# ./dataset/no3/gogobebe
# (480654,)
# wave split (480000,) OK
# ./dataset/no3/Egotistic
# (480654,)
# wave split (480000,) OK
# ./dataset/no3/Angel
# (480654,)
# wave split (480000,) OK
# ./dataset/no4/Hollywood
# (480654,)
# wave split (480000,) OK
# ./dataset/no4/SF
# (480654,)
# wave split (480000,) OK
# ./dataset/no4/Lie
# (480654,)
# wave split (480000,) OK
# ./dataset/no2/Decalcomanie
# (480654,)
# wave split (480000,) OK
# ./dataset/no2/ILoveToo
# (480654,)
# wave split (480000,) OK
# ./dataset/no2/RainySeason
# (480654,)
# wave split (480000,) OK
# ./dataset/no10/44f4a79e49f7ffcec038573e94cdab5d1b98cda6
# (480654,)
# wave split (480000,) OK
# ./dataset/no10/6831b5cca17f371165e455369c736d0166336f36
# (480654,)
# wave split (480000,) OK
# ./dataset/no10/4224ae32a34215ee7e6e5d144dbe7f418a47e7b0
# (480654,)
# wave split (480000,) OK
# ./dataset/no7/wf
# (480654,)
# wave split (480000,) OK
# ./dataset/no7/ja
# (480654,)
# wave split (480000,) OK
# ./dataset/no9/Conan Gray - Grow
# (480654,)
# wave split (480000,) OK
# ./dataset/no9/Roy Bliar - Grow Up
# (480654,)
# wave split (480000,) OK
# ./dataset/no9/Break up with your girlfriend
# (480654,)
# wave split (480000,) OK
# ./dataset/no5/EpikHigh-NOTHANXXX
# (480654,)
# wave split (480000,) OK
# ./dataset/no5/EpikHigh-Decalcomanie
# (480654,)
# wave split (480000,) OK
# ./dataset/no5/Colde-Lovestruck
# (480654,)
# wave split (480000,) OK
# ./dataset/no6/petedavidson
# (480654,)
# wave split (480000,) OK
# ./dataset/no6/SidetoSide
# (480654,)
# wave split (480000,) OK
# ./dataset/no6/Wolves
# (480654,)
# wave split (480000,) OK
# ./dataset/no1/MYMYMY
# (480654,)
# wave split (480000,) OK
# ./dataset/no1/YOUTH
# (480654,)
# wave split (480000,) OK
# ./dataset/no1/Bloom
# (480654,)
# wave split (480000,) OK

# %%
from magenta.models.nsynth import utils
from magenta.models.nsynth.wavenet import fastgen
import file_load

model_path = './wavenet-ckpt/wavenet-ckpt/model.ckpt-200000' #模型位置
npy_path = './dataset'#dataset位置
name = '.npy' #欲讀取的檔名

def wavenet_encode(file_path):
    audio = np.load(file_path)
    encoding = fastgen.encode(audio, model_path, len(audio))
    print(encoding.reshape((-1, 16)).shape)
    return encoding.reshape((-1, 16))

file_list, file_name, folder_list, folder_name = file_load.file_path(npy_path, name)

for npy, name in zip(file_list, file_name):
    print(npy)
    wavenet_data = wavenet_encode(npy)
    std_wavenet = np.std(wavenet_data, axis=0)
    mean_wavenet = np.mean(wavenet_data, axis=0)
    
    average_difference_channels = np.zeros((16,))
    
    for i in range(0, len(wavenet_data) - 2, 2):
        temp = wavenet_data[i] - wavenet_data[i+1]
        average_difference_channels += temp
    average_difference_channels /= (len(wavenet_data) // 2)   
    average_difference_channels = np.array(average_difference_channels)
    
    concat_features_wavenet = np.hstack((std_wavenet, mean_wavenet))
    concat_features_wavenet = np.hstack((concat_features_wavenet, average_difference_channels))
    
    save_path = npy.replace('.npy', "") 
    print('save',concat_features_wavenet.shape)
    np.save(save_path+'_OK',concat_features_wavenet) #存特徵向量
# Out:
# ./dataset/no8/Old School Turntables_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no8/NO THANXXX_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no8/Say what’s on your mind_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no3/Angel_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no3/gogobebe_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no3/Egotistic_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no4/Lie_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no4/SF_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no4/Hollywood_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no2/ILoveToo_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no2/RainySeason_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no2/Decalcomanie_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no10/44f4a79e49f7ffcec038573e94cdab5d1b98cda6_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no10/4224ae32a34215ee7e6e5d144dbe7f418a47e7b0_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no10/6831b5cca17f371165e455369c736d0166336f36_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no7/ja_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no7/wf_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no9/Break up with your girlfriend_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no9/Roy Bliar - Grow Up_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no9/Conan Gray - Grow_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no5/Colde-Lovestruck_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no5/EpikHigh-Decalcomanie_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no5/EpikHigh-NOTHANXXX_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no6/petedavidson_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no6/Wolves_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no6/SidetoSide_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no1/YOUTH_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no1/Bloom_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)
# ./dataset/no1/MYMYMY_0.npy
# INFO:tensorflow:Restoring parameters from ./wavenet-ckpt/wavenet-ckpt/model.ckpt-200000
# (937, 16)
# save (48,)

# %%
import file_load
import numpy as np
npy_path = './dataset/'#dataset位置
name = 'OK.npy' #欲讀取的檔名

file_list, file_name, folder_list, folder_name = file_load.file_path(npy_path, name)

for c in range(len(folder_name)):
    fi_list, fi_name, fo_list, fo_name = file_load.file_path(npy_path+'no'+str(c+1), name)
    npy_list = []
    name_list = []
    print('no'+str(c+1))
    print('')
    
    for npy, n in zip(fi_list, fi_name):
        vec = np.load(npy)
        npy_list.append(vec)
        name_list.append(n.replace('_0_OK', ''))
        print(n.replace('_0_OK', ''))
        
    if len(npy_list)==3:
        print('')
        dist = np.linalg.norm(npy_list[0]-npy_list[1])
        print(dist,'    {} 到 {}'.format(name_list[0], name_list[1]))
        dist = np.linalg.norm(npy_list[0]-npy_list[2])
        print(dist,'    {} 到 {}'.format(name_list[0], name_list[2]))
        dist = np.linalg.norm(npy_list[1]-npy_list[2])
        print(dist,'    {} 到 {}'.format(name_list[1], name_list[2]))
    
    elif len(npy_list)==2:
        print('')
        dist = np.linalg.norm(npy_list[0]-npy_list[1])
        print(dist)
    print("================")
# Out:
# no1
#
# YOUTH
# Bloom
# MYMYMY
#
# 2.830699914456322     YOUTH 到 Bloom
# 2.27186095339642     YOUTH 到 MYMYMY
# 0.8675373922773715     Bloom 到 MYMYMY
# ================
# no2
#
# RainySeason
# ILoveToo
# Decalcomanie
#
# 1.3239942531157127     RainySeason 到 ILoveToo
# 1.8122381616397454     RainySeason 到 Decalcomanie
# 2.65248001066036     ILoveToo 到 Decalcomanie
# ================
# no3
#
# gogobebe
# Egotistic
# Angel
#
# 0.48026388253221775     gogobebe 到 Egotistic
# 1.788494752006492     gogobebe 到 Angel
# 1.5435984406194327     Egotistic 到 Angel
# ================
# no4
#
# SF
# Lie
# Hollywood
#
# 1.0652123327911913     SF 到 Lie
# 1.041392130835179     SF 到 Hollywood
# 0.6575773697672002     Lie 到 Hollywood
# ================
# no5
#
# EpikHigh-Decalcomanie
# Colde-Lovestruck
# EpikHigh-NOTHANXXX
#
# 1.7957430801751673     EpikHigh-Decalcomanie 到 Colde-Lovestruck
# 0.7965891389392296     EpikHigh-Decalcomanie 到 EpikHigh-NOTHANXXX
# 2.0336525322391497     Colde-Lovestruck 到 EpikHigh-NOTHANXXX
# ================
# no6
#
# Wolves
# SidetoSide
# petedavidson
#
# 1.6356742053229116     Wolves 到 SidetoSide
# 2.803708321277067     Wolves 到 petedavidson
# 1.2793955245668986     SidetoSide 到 petedavidson
# ================
# no7
#
# wf
# ja
#
# 0.22411981138740128
# ================
# no8
#
# Old School Turntables
# Say what’s on your mind
# NO THANXXX
#
# 2.229191839178503     Old School Turntables 到 Say what’s on your mind
# 2.7560940029973193     Old School Turntables 到 NO THANXXX
# 1.2587211266927758     Say what’s on your mind 到 NO THANXXX
# ================
# no9
#
# Break up with your girlfriend
# Conan Gray - Grow
# Roy Bliar - Grow Up
#
# 1.4307349515972636     Break up with your girlfriend 到 Conan Gray - Grow
# 1.0103889632938854     Break up with your girlfriend 到 Roy Bliar - Grow Up
# 1.8629058436063843     Conan Gray - Grow 到 Roy Bliar - Grow Up
# ================
# no10
#
# 4224ae32a34215ee7e6e5d144dbe7f418a47e7b0
# 44f4a79e49f7ffcec038573e94cdab5d1b98cda6
# 6831b5cca17f371165e455369c736d0166336f36
#
# 2.3595061043764205     4224ae32a34215ee7e6e5d144dbe7f418a47e7b0 到 44f4a79e49f7ffcec038573e94cdab5d1b98cda6
# 2.229191839178503     4224ae32a34215ee7e6e5d144dbe7f418a47e7b0 到 6831b5cca17f371165e455369c736d0166336f36
# 4.2395470592691575     44f4a79e49f7ffcec038573e94cdab5d1b98cda6 到 6831b5cca17f371165e455369c736d0166336f36
# ================
