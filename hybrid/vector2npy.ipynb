# %%
import csv
import pandas as pd
import numpy as np
import ast
from ast import literal_eval

# %%
df = pd.read_csv('combine_vector.csv')
data_folder = "hybrid_vec/"

# %%
track = df.iat[1,1]
vec = df.iat[1,4]
print(track)
print(vec)
# Out:
# 00518PumkDdn560MsfLofT
# ...

# %%
len(df)
# Out:
# 11329

# %%
for i in range(0,len(df)):
    save_path = data_folder + track + '.npy'
    print(i)
    print(save_path)
    track = df.iat[i,1]
    vec = df.iat[i,4]
    vec_L = ast.literal_eval(vec)
    #print(type(vec_L))
    arr_L = np.array(vec_L)
    np.save(save_path,arr_L)
# Out:
# 0
# hybrid_vec/00518PumkDdn560MsfLofT.npy
# 1
# hybrid_vec/000xQL6tZNLJzIrtIgxqSl.npy
# 2
# hybrid_vec/00518PumkDdn560MsfLofT.npy
# 3
# hybrid_vec/009ImBOrIUlWgla8U05RAC.npy
# 4
# hybrid_vec/00AJ22EiTqG74qdgHVKVDM.npy
# 5
# hybrid_vec/00AlGnzeNVYmilww5OFUw8.npy
# 6
# hybrid_vec/00BnfL75e8vHSGCmwUWbEk.npy
# 7
# hybrid_vec/00bvlMH8B6w5kDWZjNa05M.npy
# 8
# hybrid_vec/00EQTISBxvGLzB36hiOYMd.npy
# 9
# hybrid_vec/00f9VGHfQhAHMCQ2bSjg3D.npy
# 10
# hybrid_vec/00GNc5ebF0onJaDp9Ey8bn.npy
# 11
# hybrid_vec/00J6muo7cpXzgQxLNIDC8O.npy
# 12
# hybrid_vec/00JA27dAnIPXljobCwtS36.npy
# 13
# hybrid_vec/00jXDm9BLNZdf2QC3Br0r7.npy
# 14
# hybrid_vec/00Mb3DuaIH1kjrwOku9CGU.npy
# 15
# hybrid_vec/00NAQYOP4AmWR549nnYJZu.npy
# 16
# hybrid_vec/00nKdBKPs0F7nJ0xzWbccg.npy
# 17
# hybrid_vec/00NtVG757yjm3hFVbuJX2Q.npy
# 18
# hybrid_vec/00RYw42tKwXecTaVay3BKl.npy
# 19
# hybrid_vec/00SbVevsdFCgVm4IrSbuVJ.npy
# 20
# hybrid_vec/00Tv62iZ42zDjrWYu8Rxjp.npy
# 21
# hybrid_vec/00W1p1EeD140DHSrVjhhlR.npy
# 22
# ...
