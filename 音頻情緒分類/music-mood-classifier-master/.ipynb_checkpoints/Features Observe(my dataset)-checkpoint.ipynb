# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
happy_df = pd.read_csv("additional_csv_files/DB_happy.csv")
happy_df.head(5)
# Out:
#    id           title             a_name    tempo  energy  danceability  \
# 0   1            1979  Smashing Pumpkins  126.879   0.788        -9.896
# 1   2  1-800-273-8255              Logic  100.021   0.574        -7.788
# 2   3         7 rings      Ariana Grande   70.142   0.321       -10.744
# 3   4          Acamar            Frankey  119.992   0.739        -9.089
# 4   5      All I Need       Tim Halperin  115.978   0.473        -8.900
#
#    loudness  valence  acousticness
# 0     0.765    0.964       0.01660
# 1     0.620    0.352       0.57000
# 2     0.725    0.319       0.57800
# 3     0.777    0.202       0.00212
# 4     0.611    0.133       0.58900

# %%
df = pd.read_csv("additional_csv_files/DB_happy.csv")
happy_df = df.head(100)
happy_df
# Out:
#      id                     title             a_name    tempo  energy  \
# 0     1                      1979  Smashing Pumpkins  126.879  0.7880
# 1     2            1-800-273-8255              Logic  100.021  0.5740
# 2     3                   7 rings      Ariana Grande   70.142  0.3210
# 3     4                    Acamar            Frankey  119.992  0.7390
# 4     5                All I Need       Tim Halperin  115.978  0.4730
# 5     6         Always Be My Baby       Tim Halperin  139.906  0.2550
# 6     7               Bang! Bang!           Joe Cuba  126.536  0.7760
# 7     8               Best Friend         Young Thug  127.029  0.5980
# 8     9            Billie Holiday           Warpaint  100.878  0.3850
# 9    10             Bless My Soul  Nightmares On Wax   99.989  0.5320
# 10   11       Blood On The Leaves         Kanye West  171.893  0.6810
# 11   12                  Careless              Dusky  120.986  0.8950
# ...

# %%
df = pd.read_csv("additional_csv_files/DB_relax.csv")
relax_df = df.head(100)
relax_df
# Out:
#      id                                              title  \
# 0     1                                         Accelerate
# 1     2  "Aint No Love In The Heart Of The City - Singl...
# 2     3                       All Day And All Of The Night
# 3     4                                          All of Me
# 4     5                                           Bad Liar
# 5     6                                         Be Alright
# 6     7                                         Be My Baby
# 7     8                                             Better
# 8     9                                  Better Than Today
# 9    10                                 Blood On the Money
# 10   11                              Body Like A Back Road
# 11   12                                            Bruises
# 12   13                                               Burn
# 13   14                                            Chances
# 14   15                                            Changes
# ...

# %%
df = pd.read_csv("additional_csv_files/DB_sad.csv")
sad_df = df.head(100)
sad_df
# Out:
#      id                                         title                  a_name  \
# 0     1                                     24K Magic              Bruno Mars
# 1     2                              A Million Dreams             Ziv Zaifman
# 2     3                              A Thousand Years         Christina Perri
# 3     4                                     Affection         Crystal Castles
# 4     5                                       All Day              Kanye West
# 5     6                              All of the Stars              Ed Sheeran
# 6     7              "All These Things That Ive Done"             The Killers
# 7     8                                         Alone             Alan Walker
# 8     9                                       Alright          Kendrick Lamar
# 9    10                                     Amsterdam                Coldplay
# 10   11                                         Annie             Neon Indian
# ...

# %%
df = pd.read_csv("additional_csv_files/DB_angry.csv")
angry_df = df.head(100)
angry_df
# Out:
#      id                                title               a_name    tempo  \
# 0     1                 Accidentally In Love       Counting Crows  138.017
# 1     2                           Ahora Dice          Chris Jeday  144.045
# 2     3                            All Night            The Vamps  144.997
# 3     4          Always Remember Us This Way            Lady Gaga  129.976
# 4     5                              Amazing             Westlife   97.023
# 5     6                         Anything New                Bibio   88.237
# 6     7  Bad and Boujee (feat. Lil Uzi Vert)                Migos  127.076
# 7     8                             bad idea        Ariana Grande  137.998
# 8     9                              Bam Bam         Sister Nancy  165.998
# 9    10                         Bank Account            21 Savage   75.016
# 10   11                           Better Man      Little Big Town  143.888
# ...

# %%
happy_df.describe()
# Out:
#                id       tempo      energy  danceability    loudness  \
# count  100.000000  100.000000  100.000000    100.000000  100.000000
# mean    50.500000  121.825410    0.505754     -9.511000    0.652480
# std     29.011492   27.198891    0.217086      3.303349    0.152498
# min      1.000000   48.702000    0.084500    -18.852000    0.230000
# 25%     25.750000  101.001000    0.341250    -11.311500    0.570250
# 50%     50.500000  120.940000    0.463000     -8.886500    0.670000
# 75%     75.250000  138.476500    0.682500     -7.164250    0.759500
# max    100.000000  182.126000    0.948000     -0.307000    0.959000
#
#           valence  acousticness
# count  100.000000    100.000000
# mean     0.479669      0.421110
# std      0.247692      0.323748
# min      0.034900      0.000156
# 25%      0.279500      0.063625
# 50%      0.432500      0.524000
# 75%      0.643500      0.689000
# max      0.966000      0.950000

# %%
relax_df.describe()
# Out:
#                id       tempo      energy  danceability    loudness  \
# count  100.000000  100.000000  100.000000    100.000000  100.000000
# mean    50.500000  118.981950    0.612167     -8.044110    0.597400
# std     29.011492   25.977644    0.197250      2.545605    0.148997
# min      1.000000   73.061000    0.026200    -21.668000    0.258000
# 25%     25.750000  100.037500    0.482000     -8.888250    0.494750
# 50%     50.500000  117.425000    0.609500     -7.612000    0.579500
# 75%     75.250000  131.957250    0.758500     -6.454750    0.739000
# max    100.000000  191.618000    0.987000     -3.007000    0.879000
#
#           valence  acousticness
# count  100.000000    100.000000
# mean     0.436605      0.219306
# std      0.248399      0.272718
# min      0.049900      0.000008
# 25%      0.231750      0.017550
# 50%      0.411500      0.101500
# 75%      0.597000      0.304000
# max      0.964000      0.964000

# %%
sad_df.describe()
# Out:
#                id       tempo      energy  danceability    loudness  \
# count  100.000000  100.000000  100.000000    100.000000  100.000000
# mean    50.500000  118.117890    0.664589     -6.529610    0.593490
# std     29.011492   27.864435    0.207761      2.551174    0.168048
# min      1.000000   54.747000    0.084900    -15.469000    0.167000
# 25%     25.750000   99.795750    0.523750     -6.955000    0.453000
# 50%     50.500000  115.439000    0.712500     -5.960000    0.630000
# 75%     75.250000  132.080750    0.822000     -4.748250    0.732000
# max    100.000000  209.686000    0.988000     -2.880000    0.857000
#
#           valence  acousticness
# count  100.000000    100.000000
# mean     0.430016      0.212034
# std      0.215608      0.236354
# min      0.038700      0.000004
# 25%      0.268750      0.020825
# 50%      0.403500      0.109000
# 75%      0.579000      0.356750
# max      0.962000      0.935000

# %%
angry_df.describe()
# Out:
#                id       tempo      energy  danceability    loudness  \
# count  100.000000  100.000000  100.000000    100.000000  100.000000
# mean    50.500000  117.140080    0.668920     -5.800350    0.673080
# std     29.011492   23.990082    0.144363      2.337635    0.131994
# min      1.000000   68.456000    0.188000    -14.505000    0.224000
# 25%     25.750000   99.916250    0.578500     -6.740250    0.612000
# 50%     50.500000  114.986000    0.679000     -5.381000    0.681000
# 75%     75.250000  131.033500    0.756500     -4.337750    0.744500
# max    100.000000  179.910000    0.981000     -1.157000    0.928000
#
#           valence  acousticness
# count  100.000000    100.000000
# mean     0.505654      0.128221
# std      0.231622      0.182765
# min      0.096400      0.000072
# 25%      0.327500      0.020175
# 50%      0.446500      0.061800
# 75%      0.696000      0.121000
# max      0.968000      0.825000

# %%
plt.scatter(relax_df['id'],relax_df['energy'],s=10,label='relax')

plt.xlabel("id")
plt.ylabel("energy")
plt.legend()
plt.tight_layout()

# %%
plt.scatter(sad_df['energy'],sad_df['loudness'],s=10,label='sad')
plt.scatter(angry_df['energy'],angry_df['loudness'],s=10,label='angry')
plt.xlabel("energy")
plt.ylabel("loudness")
plt.legend()
plt.tight_layout()
#angry → energy高、loudness大

# %%
plt.scatter(happy_df['energy'],happy_df['loudness'],s=10,label='happy')
plt.scatter(sad_df['energy'],sad_df['loudness'],s=10,label='sad')
plt.scatter(angry_df['energy'],angry_df['loudness'],s=10,label='angry')
plt.scatter(relax_df['energy'],relax_df['loudness'],s=10,label='relax')
plt.xlabel("energy")
plt.ylabel("loudness")
plt.legend()
plt.tight_layout()
#angry → energy高、loudness大
#happy → loudness大

# %%
plt.scatter(sad_df['energy'],sad_df['loudness'],s=10,label='sad')
plt.scatter(relax_df['energy'],relax_df['loudness'],s=10,label='relax')
plt.xlabel("energy")
plt.ylabel("loudness")
plt.legend()
plt.tight_layout()
#sad、relax → loudness大、energy高

# %%
plt.scatter(happy_df['energy'],happy_df['loudness'],s=10,label='happy')
plt.scatter(angry_df['energy'],angry_df['loudness'],s=10,label='angry')
plt.xlabel("energy")
plt.ylabel("loudness")
plt.legend()
plt.tight_layout()
#happy、angry → energy高、loudness大

# %%
plt.scatter(sad_df['id'],sad_df['energy'],s=10,label='sad')
plt.scatter(relax_df['id'],relax_df['energy'],s=10,label='relax')
plt.xlabel("id")
plt.ylabel("energy")
plt.legend()
plt.tight_layout()
#sad、relax → energy高

# %%
plt.scatter(angry_df['valence'],angry_df['energy'],s=10,label='angry')
plt.xlabel("valence")
plt.ylabel("energy")
plt.legend()
plt.tight_layout()
#angry → energy高

# %%
plt.scatter(sad_df['id'],sad_df['loudness'],s=10,label='sad')
plt.scatter(happy_df['id'],happy_df['loudness'],s=10,label='happy')
plt.xlabel("id")
plt.ylabel("loudness")
plt.legend()
plt.tight_layout()
#happy → loudness大

# %%
plt.scatter(happy_df['id'],happy_df['loudness'],s=10,label='happy')
plt.scatter(angry_df['id'],angry_df['loudness'],s=10,label='angry')
plt.xlabel("id")
plt.ylabel("loudness")
plt.legend()
plt.tight_layout()
#happy、angry → loudness大

# %%
plt.scatter(angry_df['id'],angry_df['acousticness'],s=10,label='angry')
plt.scatter(happy_df['id'],happy_df['acousticness'],s=10,label='happy')
plt.xlabel("id")
plt.ylabel("acousticness")
plt.legend()
plt.tight_layout()
#angry → acousticness低

# %%
plt.scatter(sad_df['id'],sad_df['energy'],s=10,label='sad')
plt.xlabel("id")
plt.ylabel("energy")
plt.legend()
plt.tight_layout()

# %%
plt.scatter(relax_df['id'],relax_df['energy'],s=10,label='relax')
plt.xlabel("id")
plt.ylabel("energy")
plt.legend()
plt.tight_layout()
#relax → energy高

# %%
plt.scatter(relax_df['id'],relax_df['tempo'],s=10,label='relax')
plt.xlabel("id")
plt.ylabel("tempo")
plt.legend()
plt.tight_layout()
#relax → tempo(80-140)

# %%
plt.scatter(angry_df['id'],angry_df['tempo'],s=10,label='angry')
plt.xlabel("id")
plt.ylabel("tempo")
plt.legend()
plt.tight_layout()
#angry → tempo(80-140)

# %%
plt.scatter(happy_df['id'],happy_df['tempo'],s=10,label='happy')
plt.xlabel("id")
plt.ylabel("tempo")
plt.legend()
plt.tight_layout()
#happy → tempo(90-140)

# %%
plt.scatter(sad_df['id'],sad_df['tempo'],s=10,label='sad')
plt.xlabel("id")
plt.ylabel("tempo")
plt.legend()
plt.tight_layout()
#sad → tempo(90-140)

# %%
plt.scatter(sad_df['id'],sad_df['danceability'],s=10,label='sad')
plt.xlabel("id")
plt.ylabel("danceability")
plt.legend()
plt.tight_layout()
#sad → danceability(-4~-8)

# %%
plt.scatter(happy_df['id'],happy_df['danceability'],s=10,label='happy')
plt.xlabel("id")
plt.ylabel("danceability")
plt.legend()
plt.tight_layout()
#happy → danceability(-5~-15)

# %%
plt.scatter(relax_df['id'],relax_df['danceability'],s=10,label='relax')
plt.xlabel("id")
plt.ylabel("danceability")
plt.legend()
plt.tight_layout()
#relax → danceability(-5~-11)

# %%
plt.scatter(angry_df['id'],angry_df['danceability'],s=10,label='angry')
plt.xlabel("id")
plt.ylabel("danceability")
plt.legend()
plt.tight_layout()
#angry → danceability(-3.5~-8)

# %%
plt.scatter(angry_df['id'],angry_df['danceability'],s=10,label='angry')
plt.scatter(happy_df['id'],happy_df['danceability'],s=10,label='happy')
plt.scatter(sad_df['id'],sad_df['danceability'],s=10,label='sad')
plt.scatter(relax_df['id'],relax_df['danceability'],s=10,label='relax')
plt.xlabel("id")
plt.ylabel("danceability")
plt.legend()
plt.tight_layout()
#angry → danceability

# %%
plt.scatter(sad_df['id'],sad_df['valence'],s=10,label='sad')
plt.xlabel("id")
plt.ylabel("valence")
plt.legend()
plt.tight_layout()
#sad → valence (0.2~0.6)

# %%
plt.scatter(relax_df['id'],relax_df['valence'],s=10,label='relax')
plt.xlabel("id")
plt.ylabel("valence")
plt.legend()
plt.tight_layout()
#relax → valence (0.0~0.5)

# %%
plt.scatter(angry_df['valence'],angry_df['energy'],s=10,label='angry')
plt.xlabel("valence")
plt.ylabel("energy")
plt.legend()
plt.tight_layout()
